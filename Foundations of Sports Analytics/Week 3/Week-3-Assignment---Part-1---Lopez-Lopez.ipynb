# %%
# As usual, we begin by importing the packages we will need

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# The data consists of the shot log for the NBA season 2016/17

shot = pd.read_csv("Assignment Data/Week 3/NBA shotlog_16_17.csv")
pd.set_option('display.max_columns', 100)
print(shot.columns.tolist())
shot.describe()
# Out:
# ['self_previous_shot', 'player_position', 'home_game', 'location_x', 'opponent_previous_shot', 'home_team', 'shot_type', 'points', 'away_team', 'location_y', 'time', 'date', 'shoot_player', 'time_from_last_shot', 'quarter', 'current_shot_outcome']
#           location_x         points    location_y  time_from_last_shot  \
# count  209675.000000  210072.000000  209675.00000        200072.000000
# mean      468.524507       2.316130     249.44723            33.279489
# std       345.063654       0.464965     111.02320            19.797357
# min         0.000000       2.000000       0.00000             0.000000
# 25%        94.000000       2.000000     197.00000            22.000000
# 50%       342.000000       2.000000     250.00000            31.000000
# 75%       843.000000       3.000000     303.00000            41.000000
# max       933.000000       3.000000     500.00000           255.000000
#
#              quarter
# count  210072.000000
# mean        2.480383
# std         1.136841
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         8.000000

# %%
shot['shoot_player'].unique()
# Out:
# array(['Kent Bazemore', 'Dwight Howard', 'Kyle Korver', 'Dennis Schroder',
#        'Paul Millsap', 'Tim Hardaway Jr.', 'Mike Muscala',
#        'Malcolm Delaney', 'Thabo Sefolosha', 'Kris Humphries',
#        "DeAndre' Bembry", 'Taurean Prince', 'Walter Tavares',
#        'Ryan Kelly', 'Mike Scott', 'Mike Dunleavy', 'Gary Neal',
#        'Lamar Patterson', 'Ersan Ilyasova', 'Jose Calderon',
#        'Jae Crowder', 'Al Horford', 'Avery Bradley', 'Isaiah Thomas',
#        'Jaylen Brown', 'Terry Rozier', 'Amir Johnson', 'Jonas Jerebko',
#        'Gerald Green', 'Tyler Zeller', 'Jordan Mickey', 'Marcus Smart',
#        'James Young', 'Demetrius Jackson', 'Kelly Olynyk', 'Brook Lopez',
#        'Bojan Bogdanovic', 'Jeremy Lin', 'Rondae Hollis-Jefferson',
#        'Joe Harris', 'Luis Scola', 'Sean Kilpatrick', 'Justin Hamilton',
#        'Greivis Vasquez', 'Trevor Booker', 'Chris McCullough',
#        'Anthony Bennett', 'Isaiah Whitehead', 'Randy Foye',
#        'Yogi Ferrell', 'Caris Levert', 'Spencer Dinwiddie', 'Quincy Acy',
#        'KJ McDaniels', 'Andrew Nicholson', 'Archie Goodwin',
#        'Michael Kidd-Gilchrist', 'Kemba Walker', 'Roy Hibbert',
#        'Marvin Williams', 'Marco Belinelli', 'Cody Zeller',
#        'Spencer Hawes', 'Ramon Sessions', 'Jeremy Lamb', 'Nicolas Batum',
#        'Frank Kaminsky', 'Treveon Graham', 'Brian Roberts',
#        'Christian Wood', 'Aaron Harrison', 'Miles Plumlee', 'Mike Tobey',
#        "Johnny O'Bryant III", 'Briante Weber', 'Dwyane Wade',
#        'Taj Gibson', 'Rajon Rondo', 'Robin Lopez', 'Jimmy Butler',
#        'Doug McDermott', 'Isaiah Canaan', 'Nikola Mirotic',
#        'Cristiano Felicio', 'Michael Carter-Williams', 'Bobby Portis',
#        'Denzel Valentine', 'Paul Zipser', 'Jerian Grant', 'RJ Hunter',
#        'Cameron Payne', 'Joffrey Lauvergne', 'Anthony Morrow',
#        'Kevin Love', 'LeBron James', 'Kyrie Irving', 'J.R. Smith',
#        'Tristan Thompson', 'Richard Jefferson', 'Iman Shumpert',
#        'Channing Frye', 'DeAndre Liggins', 'James Jones', 'Jordan McRae',
#        'Chris Andersen', 'Kay Felder', 'Derrick Williams',
#        'Deron Williams', 'Larry Sanders', 'Dirk Nowitzki',
#        'Harrison Barnes', 'Andrew Bogut', 'Wesley Matthews', 'Seth Curry',
#        'Dwight Powell', 'J.J. Barea', 'Justin Anderson', 'Salah Mejri',
#        'Nicolas Brussino', 'Dorian Finney-Smith', 'A.J. Hammons',
#        'Jonathan Gibson', 'Devin Harris', 'Pierre Jackson',
#        'Nerlens Noel', 'Quinn Cook', 'Ben Bentil', 'Manny Harris',
#        'Jarrod Uthoff', 'Nikola Jokic', 'Danilo Gallinari',
#        'Jusuf Nurkic', 'Emmanuel Mudiay', 'Will Barton',
#        'Wilson Chandler', 'Jameer Nelson', 'Jamal Murray',
#        'Kenneth Faried', 'Darrell Arthur', 'Juancho Hernangomez',
#        'Gary Harris', 'Malik Beasley', 'Jarnell Stokes', 'Mike Miller',
#        'Alonzo Gee', 'Mason Plumlee', 'Kentavious Caldwell-Pope',
#        'Marcus Morris', 'Tobias Harris', 'Andre Drummond', 'Ish Smith',
#        'Aron Baynes', 'Jon Leuer', 'Stanley Johnson', 'Beno Udrih',
#        'Boban Marjanovic', 'Henry Ellenson', 'Michael Gbinije',
#        'Darrun Hilliard', 'Reggie Bullock', 'Reggie Jackson',
#        'Draymond Green', 'Kevin Durant', 'Klay Thompson', 'Stephen Curry',
#        'Ian Clark', 'David West', 'Shaun Livingston', 'Andre Iguodala',
#        'Zaza Pachulia', 'Patrick McCaw', 'JaVale McGee', 'Kevon Looney',
#        'James Michael McAdoo', 'Anderson Varejao', 'Damian Jones',
#        'Matt Barnes', 'Ryan Anderson', 'Trevor Ariza', 'James Harden',
#        'Eric Gordon', 'Nene Hilario', 'Clint Capela', 'Sam Dekker',
#        'Corey Brewer', 'Tyler Ennis', 'Bobby Brown', 'Montrezl Harrell',
#        'Kyle Wiltjer', 'Patrick Beverley', 'Chinanu Onuaku',
#        'Lou Williams', 'Troy Williams', 'Isaiah Taylor', 'Myles Turner',
#        'Thaddeus Young', 'Monta Ellis', 'Paul George', 'Jeff Teague',
#        'Lavoy Allen', 'Al Jefferson', 'Rodney Stuckey',
#        'Glenn Robinson III', 'CJ Miles', 'Joe Young', 'Kevin Seraphin',
#        'George Niang', 'Rakeem Christmas', 'Aaron Brooks',
#        'Lance Stephenson', 'Chris Paul', 'JJ Redick', 'Blake Griffin',
#        'DeAndre Jordan', 'Jamal Crawford', 'Raymond Felton',
#        'Austin Rivers', 'Marreese Speights', 'Wesley Johnson',
#        'Luc Mbah a Moute', 'Diamond Stone', 'Brandon Bass',
#        'Alan Anderson', 'Paul Pierce', 'Brice Johnson', 'Julius Randle',
#        'Timofey Mozgov', "D'Angelo Russell", 'Luol Deng', 'Nick Young',
#        'Jordan Clarkson', 'Brandon Ingram', 'Larry Nance Jr.',
#        'Tarik Black', 'Marcelo Huertas', 'Thomas Robinson',
#        'Metta World Peace', 'Ivica Zubac', 'David Nwaba',
#        'JaMychal Green', 'Marc Gasol', 'Mike Conley', 'Andrew Harrison',
#        'James Ennis III', 'Wade Baldwin IV', 'Zach Randolph',
#        'Vince Carter', 'Troy Daniels', 'Jarell Martin',
#        'Elliott Williams', 'Tony Allen', 'Deyonta Davis',
#        'Chandler Parsons', 'Toney Douglas', 'Brandan Wright',
#        'Wayne Selden', 'Justise Winslow', 'Hassan Whiteside',
#        'Luke Babbitt', 'Dion Waiters', 'Goran Dragic', 'Tyler Johnson',
#        'James Johnson', 'Willie Reed', 'Rodney McGruder', 'Udonis Haslem',
#        'Josh Richardson', 'Josh McRoberts', 'Wayne Ellington',
#        'Okaro White', 'Matthew Dellavedova', 'Jabari Parker',
#        'Giannis Antetokounmpo', 'Michael Beasley', 'Greg Monroe',
#        'Malcolm Brogdon', 'Jason Terry', 'Mirza Teletovic', 'John Henson',
#        'Rashad Vaughn', 'Tony Snell', 'Thon Maker', 'Steve Novak',
#        'Khris Middleton', 'Axel Toupane', 'Terrence Jones',
#        'Gary Payton II', 'Karl-Anthony Towns', 'Andrew Wiggins',
#        'Zach LaVine', 'Gorgui Dieng', 'Ricky Rubio', 'Nemanja Bjelica',
#        'Kris Dunn', 'Brandon Rush', 'Shabazz Muhammad', 'Cole Aldrich',
#        'Tyus Jones', 'Jordan Hill', 'John Lucas III', 'Adreian Payne',
#        'Omri Casspi', "E'Twaun Moore", 'Anthony Davis', 'Tim Frazier',
#        'Omer Asik', 'Solomon Hill', 'Buddy Hield', 'Alexis Ajinca',
#        'Langston Galloway', 'Dante Cunningham', 'Cheick Diallo',
#        'Jrue Holiday', 'Anthony Brown', 'Reggie Williams', 'Tyreke Evans',
#        'Donatas Motiejunas', 'DeMarcus Cousins', 'Hollis Thompson',
#        'Jarrett Jack', 'Jordan Crawford', 'Derrick Rose',
#        'Carmelo Anthony', 'Kristaps Porzingis', 'Courtney Lee',
#        'Joakim Noah', 'Brandon Jennings', 'Lance Thomas', "Kyle O'Quinn",
#        'Justin Holiday', 'Guillermo Hernangomez', 'Mindaugas Kuzminskas',
#        'Ron Baker', 'Sasha Vujacic', 'Maurice Ndour', 'Marshall Plumlee',
#        'Chasson Randle', 'Russell Westbrook', 'Victor Oladipo',
#        'Steven Adams', 'Andre Roberson', 'Domantas Sabonis',
#        'Kyle Singler', 'Semaj Christon', 'Enes Kanter', 'Alex Abrines',
#        'Jerami Grant', 'Nick Collison', 'Josh Huestis', 'Norris Cole',
#        'Evan Fournier', 'Nikola Vucevic', 'Aaron Gordon', 'Serge Ibaka',
#        'Elfrid Payton', 'Jeff Green', 'Mario Hezonja', 'D.J. Augustin',
#        'Bismack Biyombo', 'CJ Wilcox', 'CJ Watson', 'Stephen Zimmerman',
#        'Damjan Rudez', 'Arinze Onuaku', 'Jodie Meeks', 'Terrence Ross',
#        'Marcus Georges-Hunt', 'Patricio Garino', 'Joel Embiid',
#        'Gerald Henderson', 'Dario Saric', 'Sergio Rodriguez',
#        'Jahlil Okafor', 'Richaun Holmes', 'Robert Covington',
#        'Nik Stauskas', 'TJ McConnell', 'Timothe Luwawu-Cabarrot',
#        'Jerryd Bayless', 'Justin Harper', 'Shawn Long', 'Tiago Splitter',
#        'Alex Poythress', 'Jared Dudley', 'Devin Booker', 'Tyson Chandler',
#        'Eric Bledsoe', 'TJ Warren', 'Alex Len', 'Brandon Knight',
#        'Leandro Barbosa', 'Marquese Chriss', 'Tyler Ulis',
#        'Dragan Bender', 'P.J. Tucker', 'Alan Williams', 'John Jenkins',
#        'Derrick Jones, Jr.', 'Ronnie Price', 'Jarell Eddie',
#        'Elijah Millsap', 'Al-Farouq Aminu', 'Damian Lillard',
#        'CJ McCollum', 'Allen Crabbe', 'Ed Davis', 'Evan Turner',
#        'Noah Vonleh', 'Maurice Harkless', 'Meyers Leonard', 'Jake Layman',
#        'Shabazz Napier', 'Tim Quarterman', 'Pat Connaughton', 'Ty Lawson',
#        'Kosta Koufos', 'Arron Afflalo', 'Rudy Gay', 'Anthony Tolliver',
#        'Garrett Temple', 'Ben McLemore', 'Willie Cauley-Stein',
#        'Malachi Richardson', 'Jordan Farmar', 'Skal Labissiere',
#        'Georgios Papagiannis', 'Darren Collison', 'LaMarcus Aldridge',
#        'Tony Parker', 'Pau Gasol', 'Kawhi Leonard', 'Patty Mills',
#        'Jonathon Simmons', 'Manu Ginobili', 'David Lee', 'Dewayne Dedmon',
#        'Kyle Anderson', 'Davis Bertans', 'Nicolas Laprovittola',
#        'Bryn Forbes', 'Dejounte Murray', 'Danny Green', 'Joel Anthony',
#        'DeMar DeRozan', 'Jonas Valanciunas', 'Kyle Lowry',
#        'Pascal Siakam', 'Patrick Patterson', 'Cory Joseph',
#        'Jakob Poeltl', 'DeMarre Carroll', 'Norman Powell',
#        'Lucas Nogueira', 'Fred VanVleet', 'Bruno Caboclo',
#        'Jared Sullinger', 'Delon Wright', 'Rodney Hood', 'George Hill',
#        'Joe Johnson', 'Trey Lyles', 'Joe Ingles', 'Shelvin Mack',
#        'Rudy Gobert', 'Boris Diaw', 'Dante Exum', 'Derrick Favors',
#        'Joel Bolomboy', 'Jeff Withey', 'Gordon Hayward', 'Raul Neto',
#        'Alec Burks', 'Markieff Morris', 'John Wall', 'Bradley Beal',
#        'Otto Porter Jr.', 'Marcin Gortat', 'Trey Burke',
#        'Kelly Oubre Jr.', 'Marcus Thornton', 'Jason Smith',
#        'Daniel Ochefu', 'Sheldon McClellan', 'Tomas Satoransky',
#        'Ian Mahinmi'], dtype=object)

# %%
shot['halfcourt_x'] =np.where(shot['location_x'] < 933/2, 933 - shot['location_x'],shot['location_x'])
shot['halfcourt_y'] =np.where(shot['location_x'] < 933/2, 500 - shot['location_y'],shot['location_y'])
shot.describe()
# Out:
#           location_x         points    location_y  time_from_last_shot  \
# count  209675.000000  210072.000000  209675.00000        200072.000000
# mean      468.524507       2.316130     249.44723            33.279489
# std       345.063654       0.464965     111.02320            19.797357
# min         0.000000       2.000000       0.00000             0.000000
# 25%        94.000000       2.000000     197.00000            22.000000
# 50%       342.000000       2.000000     250.00000            31.000000
# 75%       843.000000       3.000000     303.00000            41.000000
# max       933.000000       3.000000     500.00000           255.000000
#
#              quarter    halfcourt_x    halfcourt_y
# count  210072.000000  209675.000000  209675.000000
# mean        2.480383     799.731480     250.303947
# std         1.136841      89.606222     111.024160
# min         1.000000     468.000000       0.000000
# 25%         1.000000     720.000000     197.000000
# 50%         2.000000     841.000000     250.000000
# 75%         3.000000     878.000000     303.000000
# max         8.000000     933.000000     500.000000

# %%
# Comparing players

# We use a pivot table here to list players by shots

playersn = shot.groupby('shoot_player')['current_shot_outcome'].describe().reset_index()
playersn.sort_values(by = 'count', ascending = False)
# Out:
#           shoot_player count unique     top  freq
# 402  Russell Westbrook  1940      3  MISSED  1026
# 25      Andrew Wiggins  1568      3  MISSED   760
# 106      DeMar DeRozan  1545      3  MISSED   731
# 193       James Harden  1532      3  MISSED   772
# 28       Anthony Davis  1525      3  SCORED   770
# ..                 ...   ...    ...     ...   ...
# 111  Demetrius Jackson     4      2  SCORED     3
# 203       Jarrett Jack     3      2  SCORED     2
# 38          Ben Bentil     3      1  MISSED     3
# 202     Jarnell Stokes     1      1  SCORED     1
# 377          RJ Hunter     1      1  MISSED     1
#
# [485 rows x 5 columns]

# %%
# Brook Lopez plot
BLopez = shot[shot['shoot_player']=='Brook Lopez']
hxBL = BLopez['halfcourt_x']
hyBL = BLopez['halfcourt_y']
colors = np.where(BLopez['current_shot_outcome']=='SCORED','r',np.where(BLopez['current_shot_outcome']=='MISSED','b','g'))
plt.figure(figsize=(94/12,50/6))
plt.scatter(hxBL,hyBL, s=10, c= colors, marker= '.')
plt.grid(True)
plt.title("Brook Lopez", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Brook Lopez')

# %%
# Robin Lopez plot
RLopez = shot[shot['shoot_player']=='Robin Lopez']
hxRL = RLopez['halfcourt_x']
hyRL = RLopez['halfcourt_y']
colors = np.where(RLopez['current_shot_outcome']=='SCORED','r',np.where(RLopez['current_shot_outcome']=='MISSED','b','g'))
plt.figure(figsize=(94/12,50/6))
plt.xlim(500,950)
plt.scatter(hxRL,hyRL, s=10, c= colors, marker= '.')
plt.grid(True)
plt.title("Robin Lopez", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Robin Lopez')

# %%
# Brook and Robin Lopez side by side

h = plt.figure(figsize=(94/6,50/6))
ax = h.add_subplot(121)
colors = np.where(BLopez['current_shot_outcome']=='SCORED','r',np.where(BLopez['current_shot_outcome']=='MISSED','b','g'))
ax = plt.scatter(hxBL, hyBL, s=10, c= colors, marker= '.')
plt.xlim(500,950)
plt.ylim(0,500)
plt.grid(True)
plt.title("Brook Lopez", fontsize = 15)
ax = h.add_subplot(122)
colors = np.where(RLopez['current_shot_outcome']=='SCORED','r',np.where(RLopez['current_shot_outcome']=='MISSED','b','g'))
ax = plt.scatter(hxRL,hyRL, s=10, c= colors, marker= '.')
plt.xlim(500,950)
plt.ylim(0,500)
plt.grid(True)
plt.title("Robin Lopez", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Robin Lopez')
